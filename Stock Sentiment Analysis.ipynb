# %%
import pandas as pd

# %%
df = pd.read_csv('Data.csv', encoding ='ISO-8859-1')
df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %%
train_df = df[df['Date']<'20150101']
test_df = df[df['Date']> '20141231']

# %%
#X = df.drop('Label', axis =1)
#Y = df['Label']

# %%
train_df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %%
data = train_df.iloc[:,2:27]
data.replace("[^a-zA-Z]", ' ', regex = True, inplace = True)
data.head()
# Out:
#                                                 Top1  \
# 0  A  hindrance to operations   extracts from the...
# 1                                          Scorecard
# 2                  Coventry caught on counter by Flo
# 3                      Pilgrim knows how to progress
# 4                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United s rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes  instant hit buoys Blues
# 1                  Leader  German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                             Top4  \
# 0       Jack gets his skates on at ice cold Alex
# ...

# %%
train_df['Label'][:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: Label, dtype: int64

# %%
list1 = [ i for i in range(25)]
new_index = [str(i) for i in list1]
data.columns = new_index
data.head()
# Out:
#                                                    0  \
# 0  A  hindrance to operations   extracts from the...
# 1                                          Scorecard
# 2                  Coventry caught on counter by Flo
# 3                      Pilgrim knows how to progress
# 4                               Hitches and Horlocks
#
#                                     1  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United s rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                                2  \
# 0                Hughes  instant hit buoys Blues
# 1                  Leader  German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                                3  \
# 0       Jack gets his skates on at ice cold Alex
# ...

# %%
for idex in data:
    data[idex] = data[idex].str.lower()
data.head()
# Out:
#                                                    0  \
# 0  a  hindrance to operations   extracts from the...
# 1                                          scorecard
# 2                  coventry caught on counter by flo
# 3                      pilgrim knows how to progress
# 4                               hitches and horlocks
#
#                                     1  \
# 0                           scorecard
# 1                 the best lake scene
# 2  united s rivals on the road to rio
# 3                 thatcher facing ban
# 4      beckham off but united survive
#
#                                                2  \
# 0                hughes  instant hit buoys blues
# 1                  leader  german sleaze inquiry
# 2  thatcher issues defence before trial by video
# 3        mcilroy calls for irish fighting spirit
# 4                        breast cancer screening
#
#                                                3  \
# 0       jack gets his skates on at ice cold alex
# ...

# %%
headlines =[]
for row in range(0, len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[row, 0:25]))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
count = CountVectorizer(ngram_range =(2,2))
traindataset= count.fit_transform(headlines)

# %%
#print(traindataset)

# %%
randomclass = RandomForestClassifier(n_estimators=100,criterion='gini')
randomclass.fit(traindataset, train_df['Label'])
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
randomclass = RandomForestClassifier(n_estimators=300,criterion='gini')
randomclass.fit(traindataset, train_df['Label'])
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
test_transform = []
for row in range(0, len(test_df.index)):
    test_transform.append(' '.join(str(x) for x in test_df.iloc[row, 2:27]))
test_dataset = count.transform(test_transform)
predictions = randomclass.predict(test_dataset)

# %%
print(test_dataset)
# Out:
#   (0, 182)	1
#   (0, 2728)	1
#   (0, 3588)	1
#   (0, 3788)	1
#   (0, 4042)	1
#   (0, 5827)	1
#   (0, 5944)	1
#   (0, 8497)	1
#   (0, 12841)	1
#   (0, 14288)	1
#   (0, 14658)	1
#   (0, 15239)	1
#   (0, 22201)	1
#   (0, 24887)	1
#   (0, 26049)	1
#   (0, 26812)	1
#   (0, 27843)	1
#   (0, 28726)	1
#   (0, 31134)	1
#   (0, 31333)	1
#   (0, 31934)	1
#   (0, 32664)	1
#   (0, 32695)	1
#   (0, 32882)	1
#   (0, 33086)	1
#   :	:
#   (377, 527295)	1
#   (377, 540940)	1
#   (377, 544637)	1
#   (377, 544847)	1
#   (377, 545382)	1
#   (377, 546738)	1
#   (377, 551705)	1
#   (377, 552097)	1
#   (377, 554071)	1
#   (377, 555561)	1
#   (377, 559810)	1
#   (377, 561436)	1
#   (377, 566625)	1
#   (377, 568970)	1
#   (377, 571211)	1
#   (377, 572198)	1
#   (377, 573136)	1
#   (377, 573142)	1
#   (377, 574491)	1
#   (377, 576732)	1
#   (377, 577037)	1
#   (377, 578041)	1
#   (377, 580220)	3
#   (377, 580568)	1
#   (377, 581884)	1

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
matrix = confusion_matrix(test_df['Label'], predictions)

# %%
score = accuracy_score(test_df['Label'], predictions)

# %%
report = classification_report(test_df['Label'], predictions)

# %%
Final = pd.DataFrame({'Matrix_Score' : ['Confusion_Matrix' , 'Accuracy_Score', 'Report'], 'Score' : [matrix, score, report]})

# %%
Final
# Out:
#        Matrix_Score                                              Score
# 0  Confusion_Matrix                              [[131, 55], [6, 186]]
# 1    Accuracy_Score                                           0.838624
# 2            Report                precision    recall  f1-score   ...
